# %% [markdown]
# # data prepping

# %%
# dataprepping
# %pip install beautifulsoup4

# Vecotr database
# %pip install faiss-cpu
# %pip install sentence_transformers

# Ai structure
# %pip install langchain langchain_community
# %pip install ChatOpenAI
# %pip install langgraph langchain-core

# %%
def clear_kd_base():
    # Open the file in write mode to clear its contents
    with open('kd_base.json', 'w', encoding='utf-8') as f:
        # Just truncate the file without writing anything
        pass
    print("kd_base.json has been cleared")

#clear_kd_base()
# Out:
# kd_base.json has been cleared

# %%
import textwrap
import json
import bs4
import os

def get_context(filename):
    
    # part 1
    #print("this is the filename: ", filename)
    with open(filename, 'r', encoding='utf-8') as f:
        html_doc = f.read()
        file_doc = bs4.BeautifulSoup(html_doc, 'html.parser')

    main_el = file_doc.find("main")
    #print(main_el.prettify())

    title_in_main = main_el.find('h1')
    text_in_main = main_el.find_all('p')

    if title_in_main:
        print(title_in_main.get_text(strip=True))
    else:
        print("Title not found in main")

    print("")
    context = ""
    # remove style tags and <p> tags
    for p in text_in_main:
        #print(p)
        context += p.get_text(strip=True) + "\n"
    print(textwrap.fill(context, width=80))
    
    
    # part 2 save context and title into kd_base.json
    #print(f"\n{filename}")
    id = filename.split('/')[-1].split('-')[0]
    url = filename.split('/')[-1].split('.')[0]
    url = f"www.lysa.se/help-center/{url}"
    print(url)
    print("\n"+"="*80+"\n") 
    item = {
        "id": id,
        "title": title_in_main.get_text(strip=True) if title_in_main else "No title found",
        "context": context,
        "source": url
    }
    return item


    

# files = sorted(os.listdir('support_pages'))
# kd_base = {}
# for i, file in enumerate(files):
#     #print(file)
#     item = get_context(os.path.join('support_pages', file))
#     kd_base[i] = item# 

# # Write to JSON file
# with open('kd_base.json', 'a+', encoding='utf-8') as f:
#     json_str = json.dumps(kd_base, ensure_ascii=False, indent=4)
#     f.write(json_str)

with open('kd_base.json', 'r', encoding='utf-8') as f:
    kd_base = json.load(f)
    print("Loaded", len(kd_base), "items from kd_base.json")
# Out:
# Investera i fonder eller spara på Sparkonto Auto?
#
# Investera i fonderAtt investera i fonder ger möjlighet till god avkastning över
# tid. Samtidigt innebär det en risk att pengarna minskar i värde. Hos oss
# investeras dina pengar i en portfölj av aktie- och räntefonder som anpassas
# efter dina behov. Detta är lämpligt för sparande på minst ett år där möjlighet
# till god avkastning är viktigare än låg risk.Dina pengar sätts in på ett ISK
# (investeringssparkonto).Spara på Sparkonto AutoSparkonto Auto är en trygg
# sparform som innebär att du kan få ränta på dina pengar samtidigt som de är
# skyddade av den statliga insättningsgarantin. Det är lämpligt för exempelvis
# buffertsparande eller kortsiktiga sparmål där låg risk är viktigare än hög
# avkastning.Dina pengar sätts in på ett Sparkonto Auto.
# www.lysa.se/help-center/157-investera-i-fonder-eller-spara-pa-sparkonto-auto
#
# ================================================================================
#
# Vilka är Lysas samarbetspartners?
#
# Lysa samarbetar för närvarande med Collector (Norion Bank AB) och Borgo för att
# tillhandahålla Sparkonto Auto.Collector erbjuder privatlån och kreditkort till
# privatpersoner samt sparkonton till privatpersoner och företag. Med fokus på
# sund och hållbar kreditgivning hjälper Collector kunder att låna tryggt utan
# säkerhet. Collector är ett varumärke inom Norion Bank AB (tidigare Collector
# Bank AB), Org.nr 556597-0513, som grundades 1999 och har kontor i Göteborg,
# Stockholm, Helsingborg, Oslo och Helsingfors. Verksamheten bedrivs genom Norion
# Bank AB (publ) som är noterat på Nasdaq Stockholm och står under
# Finansinspektionens tillsyn.Läs mer om Collector och Norion Bank AB på
# https://www.norionbank.se/norion-bank-group-se.Borgo AB (publ) (“Borgo”), Org.nr
# 559153-2303, är ett fristående hypoteksbolag som erbjuder konkurrenskraftiga
# bolån via kreditförmedlare till svenska privatpersoner. Borgo erbjuder även
# sparkonton till privatpersoner och företag. Borgo har tillstånd att bedriva
# kreditmarknadsbolag enligt lagen om bank- och finansieringsrörelse samt enligt
# lag om utgivning av säkerställda obligationer och står under tillsyn av
# Finansinspektionen.Mer information om Borgo finns på Borgos webbplats:
# https://www.borgohypotek.se/om-oss.
# www.lysa.se/help-center/168-vilka-aer-lysas-samarbetspartners
#
# ================================================================================
#
# Vad kostar Lysa?
#
# Låga avgifter ärotroligt viktigt för ett framgångsrikt långsiktigt sparande. Ju
# lägre avgift du betalar för ditt sparande (dag efter dag, år efter år), desto
# mer pengar blir kvar på ditt konto och får möjlighet att växa. Lysas
# genomsnittskund betalar ca 0,40 % i total avgift per år.Den totala avgiften
# består av tre delar:1. Avgiften som går till Lysa (portfölj- och
# fondförvaltningsavgift)2. Avgiften som går till de fonder som vi investerar dina
# pengar i (underliggande fondavgifter)3. Avgiften för att handla dessa fonder
# (transaktionskostnader)Utöver detta tillkommer inga andra avgifter. Vi tar inte
# ut någon avgift för plattformen eller för att göra insättningar och uttag. Det
# medför att mer pengar blir kvar till dig som kund.Om du vill se vad din avgift
# skulle bli kan du göra dethär.
# www.lysa.se/help-center/170-vad-kostar-lysa
#
# ================================================================================
#
# Hur kommer jag igång? (Privatperson)
#
# Att bli kund hos Lysa är enkelt och det tar bara några minuter att komma igång
# med sparandet. Det kostar inget att bli kund utan du betalar enbart avgift på
# ditt samlade kapital hos oss. För att bli kund behöver du vara minst 18 år
# gammal, ha tillgång till ett BankID och ha din primära skatterättsliga hemvist i
# Sverige. Du kan registrera dig vialysa.seeller vår app. Följ dessa steg för att
# komma igång med ditt sparande på Lysa:1. Svara på några frågor om digKlicka
# på“Bli kund”pålysa.seeller i appen för att inleda registreringsprocessen.
# Besvara några frågor om din erfarenhet, ekonomiska situation, syn på risk och
# investeringshorisont. Detta för att vi ska kunna avgöra om 1) tjänsten är
# lämplig för dig och 2) ge ett investeringsförslag anpassat till din situation
# och sparmål. Därefter får du välja investeringsfokus (bred eller hållbar) och ta
# del av vårt investeringsförslag. 2. Kundkännedom och signering med BankIDNär du
# godkänt investeringsförslaget besvarar du några kundkännedomsfrågor och därefter
# signerar du avtalet och blir kund med hjälp av BankID. Därefter startas ett
# Lysakonto (ISK-konto) i ditt namn med din valda målfördelning. 3. Gör en första
# insättningNu har du ditt konto! Det enda som återstår är att göra din första
# insättning. Du hittar våra insättningsmetoder via“Insättningar”uppe till höger
# på hemsidan eller på knappen“Sätt in pengar”i vår app.  Det går även att
# registrera ett månadssparande med autogiro. På hemsidan klickar du på huvudmenyn
# till vänster, sedan“Insättningar”och“Månadssparande”. I vår app kan du klicka
# på“Sätt in pengar”och sedan“Skapa månadssparande”. När din insättning inkommit
# till ditt konto investeras den automatiskt i enlighet med din valda
# målfördelning inom 1-3 bankdagar. Enkelt, automatiskt och smidigt!
# www.lysa.se/help-center/173-hur-kommer-jag-igang-privatperson
#
# ================================================================================
#
# Varför omfattas Sparkonto Auto av en avgift?
#
# Banker som erbjuder sparkonto tjänar pengar på att låna ut de pengar som sätts
# in på kontot till en högre ränta än de betalar för att låna in dem (skillnaden
# mellan räntan på sparkontot och räntan för ett lån, t.ex. ett bolån). Lysa är
# ingen bank och kan därför inte tjäna pengar på kunders insättningar på detta
# vis. För att kunna erbjuda Sparkonto Auto behöver Lysa alltjämt en intjäning
# från produkten.Genom att ta betalt direkt från dig som kund istället för via
# kickbacks och andra dolda intjäningskanaler så kan vi minimera risken för
# intressekonflikter och alltid göra det som är bäst för dig som kund. Vi strävar
# även efter att vara transparenta med vad vi tjänar pengar på och hur mycket du
# som kund har betalat och kommer att betala.
# www.lysa.se/help-center/176-varfoer-omfattas-sparkonto-auto-av-en-avgift
#
# ================================================================================
#
# Hur beskattas räntan jag får via Sparkonto Auto?
#
# Ränta som du erhåller från Lysas samarbetspartners via ditt Sparkonto Auto som
# överstiger 100 kronor rapporteras till Skatteverket (kontrolluppgift) och kommer
# förtryckt i din deklaration som en inkomst i inkomstslaget kapital.
# Kapitalvinster, dvs. överskott i inkomstslaget kapital, beskattas som
# utgångspunkt med 30 % (från första kronan).Ränta som understiger 100 kronor
# rapporteras inte in till Skatteverket och är som utgångspunkt skattefri.Notera
# att det är räntan du får innan avdrag för Lysas avgift som är föremål för
# (eventuell) skatt, vilket kan illustreras med följande exempel:Rörlig ränta:
# 3,75 %Lysas avgift: 0,24 %Insättning vid årets början:100 000 krRänta: 100 000 x
# 3,75 % = 3 750 krAvgift: 100 000 x 0,24 % = 240 krKontots värde vid årets
# slut:100 000 + 3 750 - 240 = 103 510 krBelopp som är föremål för skatt: 3 750 kr
# www.lysa.se/help-center/177-hur-beskattas-raentan-jag-far-via-sparkonto-auto
#
# ================================================================================
#
# Vad är Lysa?
#
# Lysa är en spartjänst som automatiskt investerar dina pengar i några av
# marknadens bredaste ochbilligasteindexfonder och ränteinstrument. Dessutom
# anpassas risknivån i ditt sparande baserat på just din situation och dina
# preferenser. Med Lysa Sparkonto kan du även samla din buffert samt dina
# kortsiktiga sparmål hos oss. Dina pengar ärlika säkra på Lysa som hos din
# bankoch du kan göra insättningar och uttag när du vill. Lysa ger dig ett smart
# sparande som sköter sig själv, helt enkelt.Hur investeras mina pengar med
# Lysa?Vår investeringsfilosofi bygger på historisk data, sannolikhetslära och
# nobelprisvinnande forskning i ekonomi. Detta samt insikten om att ingen kan se
# in i framtiden och därigenom veta exakt vilka aktier eller fonder som kommer
# prestera bättre än andra. Genom att investera brett och billigt (globalt och
# indexnära) är ditt sparande på Lysa utformat för att vara förberett på att
# precis vad som helst kan hända. Vår tjänst bygger på fyra enklagrundprinciper:1.
# Betala låga avgifter2. Sprid dina investeringar - god diversifiering minskar
# risken3. Ta inte större risker än du kan hantera4. Fullfölj din sparstrategi Med
# Lysa får du ett evidensbaserat sparande baserat på hur forskning och historisk
# data säger att du bör investera dina pengar. Klickahärför att komma igång med
# Lysa redan idag som privatperson. Du kan även läsa vidare nedan för att lära dig
# mer om våra grundprinciper och hur Lysa hjälper dig till ett bättre
# sparande.Betala låga avgifterEn av de viktigaste aspekterna för ett framgångsrik
# sparande är att betala låga avgifter. Ju mindre du betalar i årliga avgifter
# desto mer blir kvar till dig för att öka i värde över tid. Betalar du i stället
# höga avgifter urholkas kapitalet mer från år till år och gör att du som sparar
# får mindre kvar som kan fortsätta växa åt dig.Föreställ dig två personer (A och
# B) som båda börjar med 100 000 kr och har ett löpande månadssparande på 3 000 kr
# varje månad. Bådas fondsparande genererar i genomsnitt en avkastning på 7 % per
# år (vilket är vad man kan förvänta sig för aktiefonder). Den enda skillnaden är
# att person A betalar 0,4 % i avgift varje år medan person B betalar 1,5 % per
# år.Person A Person B Exemplet illustrerar är att ju längre tiden går, desto
# tydligare blir dennegativa effekten av att löpande betala högre avgifter. De
# höga avgifterna gör att person B har nästan 5,5 miljoner mindre på sitt konto
# jämfört med person A efter 50 års sparande. Detta trots att de satt in exakt
# lika mycket pengar till sina konton.Hos Lysa betalar du ungefär 0,4 % per år i
# total avgift. Faktum är att du förmodligen kommer betala mindre än så. Dessutom
# arbetar vi ständigt för att sänka våra kunders avgifter ytterligare. Detta för
# att göra ditt sparande ännu bättre och billigare.Hittills har vi genomfört ett
# flertal sänkningar av avgiften.Sprid dina investeringar - god diversifiering
# minskar riskenDiversifiering innebär att du sprider dina investeringar i fler
# värdepapper eller tillgångar. När antalet bolag i din portfölj ökar kan du
# förvänta dig en mer stabil avkastning eftersom dina pengar fördelats i fler
# bolag. Du blir alltså inte lika beroende av varje enskilt bolags utveckling och
# då minskar risken i ditt sparande. Det är även viktigt att sprida dina
# investeringar geografiskt över olika länder. På så vis minskar även risken
# relaterad till enskilda länders ekonomier, valutor och politiska situation. Hos
# Lysa väljer du mellan våra två investeringsfokus - bred och hållbar. Oavsett val
# av fokus får du en bred och väldiversifierad portfölj med riskspridning över
# hela världen. I Lysa Bred investeras dina pengar i mer än 7 000 bolag, medan det
# hållbara fokusområdet ger exponering mot drygt 1 000 bolag. Du kan läsa mer om
# våra investeringsfokushär.Ta inte större risker än du kan hanteraAtt investera i
# aktier och räntor innebär alltid en risk och värdet på investeringen kan både
# öka och minska i värde. Det finns ingen garanti för att du får ut mer pengar än
# du har satt in, men historiskt har både aktier och räntor en positiv
# genomsnittlig avkastning över tid. Baserat på historisk data kan du förvänta dig
# ungefär 7 % i genomsnittlig årlig avkastning för aktier och ungefär 1,5 % för
# räntor. Med det sagt är detta inte en linjär sanning utan avkastningen kan
# variera kraftigt från år till år.Aktier är alltså förknippade med högre
# förväntad avkastning än räntor men kommer även med en högre risk (på grund av
# högre volatilitet). Det innebär att utvecklingen i genomsnitt varierar mer än
# för räntor under varje given tidsperiod.Därför är det viktigt att säkerställa
# att du har en risknivå som du kan hantera i ditt sparande.På Lysa hjälper vi dig
# att hitta rätt risknivå i ditt sparande utifrån dina förutsättningar,
# preferenser och sparhorisont. Därefter ser vi till att bibehålla samma risknivå
# över tid genom så kallade ombalanseringar, och på så vis säkerställer vi att du
# får en så god riskjusterad avkastning som möjligt. Genom att göra detta behöver
# duinte oroa dig när börsen går nedoch vi ser även till att du inte tar mer risk
# än vad som är lämpligt för dig. Allt för att du ska känna dig trygg med ditt
# sparande, oavsett vad som händer i världen och på börsen.Fullfölj din
# sparstrategiIngen vet hur framtiden ser ut eller hur världens börser kommer att
# påverkas av olika händelser. Därför är det oerhört svårt att konsekvent tajma
# marknadens upp- och nedgångar. Genom att titta på historisk data kan vi däremot
# se att sannolikheten för att börsen på lång sikt går upp är högre än att den går
# ned. Därför är det viktigt att inte låta känslorna styra vid tillfälliga
# nedgångar på världens börser, utan att istället hålla sig till sin långsiktiga
# sparplan.Följer du det investeringsförslag vi skapar åt dig när du blir kund får
# du en risknivå i ditt sparande anpassat till just din situation och ditt
# sparmål. Detta för att öka chanserna att du fullföljer din sparplan och för att
# du ska kunna sova gott om natten, både när börsen går upp och ner. Läs gärna mer
# om vikten av att följa din sparstrategihär.
# www.lysa.se/help-center/179-vad-aer-lysa
#
# ================================================================================
#
# Vad är en fond?
#
# En fond utgörs av ett antal underliggande värdepapper där du äger fondandelarna
# gemensamt med de andra andelsägarna. Du väljer inte själv vilka värdepapper som
# ingår i fonden, utan det bestäms av fondförvaltaren. På Lysa investeras dina
# pengar i några av marknadens, enligt oss bästa indexnära aktie- och
# räntefonder.Indexnära aktiefonderEn indexfond följer ett specifikt index för att
# efterlikna dess värdeutveckling, t.ex. den svenska aktiemarknaden. Det betyder
# att innehaven i en sådan indexfond ska efterlikna bolagens storlek på den
# svenska aktiemarknaden. Förvaltaren av en indexfond har till uppgift att
# säkerställa fonden så väl som möjligt, med hänsyn till kostnader, efterliknar
# index. Förvaltaren väljer inte själv ut innehav eller letar efter enskilda
# aktier som kommer att öka i värde. Detta medför att förvaltningskostnaden för
# indexfonder är lägre jämfört med aktivt förvaltade fonder.I en aktivt förvaltad
# fond väljer fondförvaltaren själv ut innehaven och deras vikt i fonden i hopp om
# att dessa ska prestera bättre än sitt jämförelseindex. Det manuella arbetet
# förknippat med den analys som görs medför att förvaltningskostnaden för en
# aktivt förvaltad fond ofta blir högre än för en indexfond.Forskning visar att
# tre av fyra aktivt förvaltade fonder underpresterar jämfört med sitt
# jämförelseindex varje enskilt år. Detta antyder att det inte finns något sätt
# att i förväg identifiera vilka tillgångar som kommer generera en positiv
# riskjusterad avkastning.Dessutom visar forskningatt de fonder som presterat
# bättre än index under ett år inte nödvändigtvis presterar bättre följande
# år.Anledningen till att Lysa föredrar indexnära aktiefonder är att avgifterna är
# lägre samt att det inte finns några bevis för att aktivt förvaltade fonder
# genererar en bättre avkastning än sitt jämförelseindex över tid. Det leder till
# att andelsägare i aktivt förvaltade fonder ofta betalar högre avgifter till en
# lägre avkastning. Genom att investera globalt i hela marknaden, ökar våra
# kunders diversifiering vilket i sin tur minskar risken.RäntefonderEn räntefond
# är en fond som investerar i räntebärande värdepapper. Räntefondens funktion i en
# portfölj är att ge stabilitet och undvika stora värdeminskningar vid oroliga
# börstider. Räntor kan alltså liknas med en krockkudde för portföljen.Det finns
# många typer av ränteinstrument. De påverkas olika av olika marknadslägen och
# även det rådande ekonomiska ränteläget. En vanlig kategorisering av räntefonder
# är mellan korta och långa räntefonder. Det som skiljer dem åt är löptiden för de
# underliggande ränteinstrument fonden investerar i. Alltså när lånet ska betalas
# till den som lånat ut pengar. Korta räntefonders underliggande innehav har en
# löptid kortare än ett år och långa räntefonder har innehav med en löptid längre
# än ett år. Långa räntor är förknippade med högre risk än korta räntor eftersom
# de kommer att påverkas av fler omvärldshändelser under lånens löptid.De
# räntefonder som Lysa investerar i ger en bred exponering mot flertalet olika
# tillgångar inom räntor, vilket för dig som kund, innebär att dina
# ränteinvesteringar diversifieras. Vi investerar i svenska bostads-, företags-
# och statsobligationer samt realobligationer och därtill investerar vi i globala
# stats- och företagsobligationer. Därmed är ränteportföljen beredd för olika
# scenarion och ger ditt sparande en stabil grund för att över tid skapa en
# positiv avkastning efter inflation.
# www.lysa.se/help-center/191-vad-aer-en-fond
#
# ================================================================================
#
# Hur sätts räntan?
#
# Räntan bestäms alltid av Lysas samarbetspartners. Den avgörs av vilken
# inlåningsränta de beslutar om att erbjuda. Det här är således inget Lysa
# beslutar om. Du kan alltid hitta din nuvarande rörliga ränta på kontosidan för
# ditt sparkonto.
# www.lysa.se/help-center/199-hur-saetts-raentan
#
# ================================================================================
#
# Vad innebär en "väntande fondorder"?
#
# Om du nyligen gjort en insättning, intern överföring eller uttag på ditt
# Lysakonto har du en “väntade fondorder”. Det är normalt och betyder att din
# pågående fondorder måste gå igenom innan du kan begära en intern överföring
# eller uttag. Detta tar cirka 1-3 bankdagar. Du får ett mejl när din transaktion
# är klar.
# www.lysa.se/help-center/213-vad-innebaer-en-vaentande-fondorder
#
# ================================================================================
#
# Kan jag göra en ISK-flytt från Lysa?
#
# Ja, det går bra. För att göra en ISK-flytt från Lysa tar du kontakt med det
# mottagande institutet du vill flytta till så hjälper de dig med ett
# flyttuppdrag. Du kan inte flytta delar av ditt kontovärde utan du måste begära
# en försäljning och flytt av hela innehavet. I flyttuppdraget är det därför
# väldigt viktigt att du fyller i att ditt fondinnehav ska säljas och att
# likviderna sedan ska flyttas till ditt ISK hos det mottagande institutet.Där
# kontonummer för din ISK ska anges i flyttuppdraget kan du ange ditt Lysakontos
# OCR-nummer för bankgiroinsättningar. Detta då Lysa inte är en bank och därmed
# har ditt Lysakonto inte ett traditionellt kontonummer. Du hittar OCR-nummer för
# bankgiroinsättningar genom följande steg: Hemsida: > Logga in med BankID
# pålysa.seoch klicka på menyn med tre streck uppe till vänster>
# Välj“Överföringar”sen"Insättningar"och“Bankgiro”> Klicka sedan på det Lysakontot
# du vill se OCR-nummer för  App: > Logga in med BankID via appen> Klicka på
# knappen“Sätt in pengar”> Sedan väljer du“Bankgiro”och vilket konto du vill se
# OCR-nummer för
# www.lysa.se/help-center/214-kan-jag-goera-en-isk-flytt-fran-lysa
#
# ================================================================================
#
# Kan jag göra en ISK-flytt till Lysa?
#
# Ja, det går bra att göra en ISK-flytt till Lysa! Det innebär att du enkelt kan
# flytta ditt sparande från ett investeringssparkonto (ISK) hos ett annat institut
# till ditt Lysakonto. Eftersom flytten sker direkt mellan två ISK-konton utlöser
# den ingen skatt, och Lysa tar inte ut någon flyttavgift. En ISK-flytt tar
# normalt 2–4 veckor, men tiden kan variera beroende på vilket institut du flyttar
# från, eftersom det är de som ansvarar för själva genomförandet. Lysa följer dock
# alltid upp processen och gör vårt yttersta för att din flytt ska gå så snabbt
# och smidigt som möjligt. Du kan välja mellan två typer av ISK-flytt: Flytta hela
# innehavet som likvid – Då säljs alla fonder automatiskt och pengarna förs över
# till Lysa. Observera att om du har aktier, certifikat, warranter eller ETF:er
# behöver du sälja dem själv innan du registrerar flytten. Flytta en valfri summa
# (minst 5 000 kr) – Pengarna måste vara oinvesterade på ditt ISK-konto vid
# flytten. Om de är investerade i värdepapper behöver du först sälja av dem själv.
# Du kan begära en ISK-flytt till Lysa viahemsidaneller appen. Gör enligt
# följande: Hemsidan: > Logga in med BankID och klicka på menyn med tre streck
# uppe till vänster > Välj “Överföringar” och “ISK-flytt” > Följ stegen för att
# registrera en ISK-flytt till Lysa Appen: > Logga in med BankID och klicka på
# knappen “Sätt in pengar” > Välj "ISK-flytt" som insättningsmetod > Följ stegen
# för att registrera en ISK-flytt till Lysa
# www.lysa.se/help-center/215-kan-jag-goera-en-isk-flytt-till-lysa
#
# ================================================================================
#
# Hur kan jag göra en återkommande utbetalning?
#
# Du kan enkelt lägga upp en återkommande utbetalning om du vill ha en stående
# överföring från Lysa till din bank. Det finns tre typer av återkommande
# utbetalningar - procentuell, fast eller en utbetalningsplan med måldatum.  För
# att lägga upp ett återkommande uttag gör du följande: > Logga in med BankID
# pålysa.seoch klicka på menyn med tre streck uppe till vänster >
# Välj“Överföringar”och“Uttag” > Sedan väljer du“Gå vidare”under“Återkommande
# utbetalningar”längst ned på sidan
# www.lysa.se/help-center/217-hur-kan-jag-goera-en-aterkommande-utbetalning
#
# ================================================================================
#
# Hur gör jag ett uttag?
#
# Du kan enkelt begära ett kostnadsfritt uttag viahemsidaneller appen. Gör enligt
# följande: Hemsidan: > Logga in med BankID pålysa.seoch klicka på menyn med tre
# streck uppe till vänster > Välj“Överföringar”och“Uttag” > Följ stegen efter att
# du klickat på“Nytt uttag”  Appen: > Logga in med BankID och bläddra längst ned
# till“Genvägar”och klicka på“Uttag” > Följ stegen under“Ta ut pengar”  Från att
# du begärt uttaget tar det cirka 1-3 bankdagar innan pengarna finns hos din bank.
# Om du inte tidigare gjort ett uttag från Lysa behöver du först lägga till ett
# bankkonto. Läs mer hur du går tillvägahär.
# www.lysa.se/help-center/218-hur-goer-jag-ett-uttag
#
# ================================================================================
#
# Hur beräknas avkastningen på mitt Lysakonto?
#
# Din utveckling ikronoranger din värdeförändring under vald period genom att
# subtrahera nuvarande marknadsvärde på innehaven med den summa som satts in
# (nettoinsättningar). Avkastningen i kronor påverkas av dina insättningar och
# uttag, dels deras storlek men även när de gjorts och till vilka kurser i de
# underliggande fonderna.Din utveckling iprocentanger hur underliggande innehav i
# din portfölj utvecklats under den valda tidsperioden och tar inte hänsyn till
# insättningar eller uttag på kontot. Beräkningsmetoden kallas TWR (Time Weighted
# Return) och används av finansbolag för att du som kund ska kunna jämföra
# utvecklingen av din portfölj med andra fonder och portföljer. Du kan läsamerhär
# kring varför vi valt TWR över andra beräkningsmetoder för procentuell
# utveckling.Utvecklingen i kronor och procent beräknas alltså på olika sätt,
# därför kan de skilja sig åt. Anledningen är att storleken på insättningar eller
# uttag påverkar storleken på din avkastning i kronor men inte din avkastning i
# procent. Det kan alltså uppstå situationer där din avkastning är positiv i
# procent men negativ i kronor och vice versa. Det är naturligt och beror just på
# att utvecklingen beräknas på olika sätt.Se nedan exempel för en förklaring till
# varför utvecklingen i kronor och procent kan skilja sig åt.Du investerar 10 000
# kr på ditt konto.Investeringen ökar i värde med 10 %: 10 000 kr * (+0,10) = +1
# 000 krTotalt har du nu: 10 000 kr + 1 000 kr = 11 000 krUtveckling i procent:
# +10 %Utveckling i kronor: +1 000 krDu gör nu en ny insättning på 150 000 kr och
# du har nu alltså 161 000 kr totalt på ditt konto.Investeringen minskar nu i
# värde med 5 %: 161 000 kr * (-0,05) = -8 050 kr.Totalt har du nu: 161 000 kr - 8
# 050 kr = 152 950 krUtveckling i procent: (1+0,1)*(1-0,05)-1 = 1,045-1 = 0,045
# (+4,5 %)Utveckling i kronor: 152 950 - 160 000 = -7 050 krHur ska detta tolkas?
# Det innebär att dina underliggande innehav i portföljen under de här månaderna
# gått upp med totalt 4,5 % men värdet på din portfölj är 7 050 kr lägre än det du
# satt in. Detta på grund av den extra insättning du gjort och att börsen gått ned
# efter att du gjorde den andra insättningen.
# www.lysa.se/help-center/220-hur-beraeknas-avkastningen-pa-mitt-lysakonto
#
# ================================================================================
#
# När uppdateras min utveckling på mitt Lysakonto?
#
# Utvecklingen på ditt Lysakonto uppdateras en gång per bankdag och baseras på
# föregående bankdags utveckling för de underliggande innehaven. Kurserna brukar
# uppdateras runt lunchtid, men viss variation kan förekomma.
# www.lysa.se/help-center/221-naer-uppdateras-min-utveckling-pa-mitt-lysakonto
#
# ================================================================================
#
# Vad är Lysas investeringsfilosofi?
#
# Lysa är en spartjänst som automatiskt investerar dina pengar i några av
# marknadens bredaste och billigaste indexnära aktiefonder och ränteinstrument.
# Dessutom anpassas risknivån i ditt sparande baserat på just din situation och
# dina preferenser. Vår investeringsfilosofi bygger på historisk data,
# sannolikhetslära och nobelprisvinnande forskning i ekonomi. Detta samt insikten
# om att ingen kan se in i framtiden och därigenom veta exakt vilka aktier eller
# fonder som kommer prestera bättre än andra. Genom att investera brett (globalt
# och indexnära) och billigt är ditt sparande på Lysa utformat för att vara
# förberett på att precis vad som helst kan hända. Vår tjänst bygger på fyra
# enklagrundprinciper:1. Betala låga avgifter2. Sprid dina investeringar - god
# diversifiering minskar risken3. Ta inte större risker än du kan hantera4.
# Fullfölj din sparstrategiDu kan läsa merhärom Lysas investeringsfilosofi.
# www.lysa.se/help-center/222-vad-aer-lysas-investeringsfilosofi
#
# ================================================================================
#
# Vilken avkastning kan jag förvänta mig?
#
# Målet med förvaltningen är att maximera din avkastning, givet din ekonomiska
# situation, risktolerans och sparhorisont.Lysas investeringsfilosofiinnebär att
# din utveckling kommer att vara förknippad med marknadsutvecklingen och anpassad
# till dina förutsättningar och preferenser. På så vis hjälper vi dig att maximera
# din riskjusterade avkastning.
# www.lysa.se/help-center/223-vilken-avkastning-kan-jag-foervaenta-mig
#
# ================================================================================
#
# Vilka fonder investerar Lysa i?
#
# För att hitta underliggande innehav i dina fonder gör du följande:  Hemsidan: >
# Logga in med BankID och klicka på"Visa mer"på önskat Lysa-konto > Under
# rubriken“Innehav”kan du se underliggande innehav  Appen: > Logga in med BankID >
# Välj kontot bland"Mina konton" > Skrolla ned till"Innehav" > Välj"Aktier"för att
# kunna se underliggande innehav i aktiefonderna och välj"Räntor"för att se
# underliggande innehav i räntefonderna
# www.lysa.se/help-center/224-vilka-fonder-investerar-lysa-i
#
# ================================================================================
#
# Kan jag byta investeringsfokus?
#
# Ja, du kan byta investeringsfokus (välj mellan brett och hållbar) på ditt
# Lysakonto. Det är helt kostnadsfritt och tar cirka 1-3 bankdagar. Gör följande
# för att byta investeringsfokus: Hemsidan:> Logga in med BankID och klicka på
# menyn med tre streck uppe till vänster> Välj “Kundinfo” och
#  “Investeringsprofil”> Kontrollera uppgifterna om din ekonomi och uppdatera om
# något har förändrats> Klicka på nästa och välj investeringsfokus under "Hur vill
# du investera?" ("Så brett som möjligt" eller "Med fokus på hållbarhet")> Klicka
# dig genom flödet och bekräfta dina ändringar genom att klicka på "Nästa"  App: >
# Logga in med BankID på appen> Välj konto under "Mina konton"> Klicka på "Ändra"
# under "Kontofokus"> Klicka dig genom flödet "Ändra kontofokus" genom att klicka
# svara på frågorna och på "Fortsätt"> Kontrollera uppgifterna om din ekonomi och
# uppdatera om något har förändrats. Klicka dig genom flödet och bekräfta dina
# ändringar genom att klicka på "Bekräfta"
# www.lysa.se/help-center/225-kan-jag-byta-investeringsfokus
#
# ================================================================================
#
# Kan jag ha flera konton hos Lysa?
#
# Ja, du kan ha så många konton du vill och det kostar inget att öppna fler
# konton. Gör följande för att öppna ett ISK-konto eller sparkonto:Appen:> Logga
# in med mobilt BankID> Klicka på"Nytt konto"vid rubriken"Mina konton"på
# startsidanHemsidan:> Logga in med mobilt BankID pålysa.se> Klicka på"Öppna konto
# +"i kontoöversikten
# www.lysa.se/help-center/226-kan-jag-ha-flera-konton-hos-lysa
#
# ================================================================================
#
# Kan jag spara åt mina barn eller barnbarn hos Lysa?
#
# Att spara till barn eller barnbarn är populärt bland våra kunder. Du kan öppna
# ett Lysakonto (ISK) i ditt namn och låta sparandet vara ämnat för barnet/barnen.
# På detta sätt har du full kontroll över när ditt barn ska få tillgång till
# pengarna. Du kan däremot inte öppna ett Lysakonto i en minderårigs namn.Du kan
# dessutom dela kontot med din partner och på så sätt kan båda ha vetskap om
# sparkapitalet.Läs merhärom hur du delar ditt konto.
# www.lysa.se/help-center/227-kan-jag-spara-at-mina-barn-eller-barnbarn-hos-lysa
#
# ================================================================================
#
# Hur gör jag för att avsluta mitt sparande hos Lysa?
#
# För att avsluta ditt engagemang gör du följande:  Hemsidan: > Logga in med
# BankID och klicka på menyn med tre streck uppe till vänster >
# Välj“Kundinfo”och“Inställningar” > Sedan väljer du“Avsluta konto eller
# engagemang hos Lysa”och“Avsluta mitt engagemang hos Lysa”  Appen: > Logga in med
# BankID och klicka på menyn med tre streck nere till höger > Bläddra ner till
# rubriken"Annat" > Klicka på"Avsluta ditt engagemang hos Lysa"och följ stegen för
# att avsluta ditt engagemang  När du kryssat i och bekräftat att du önskar att
# avsluta ditt engagemang kommer alla fondandelar att säljas av. Därefter överförs
# beloppet till ditt föranmälda bankkonto. Hela processen tar cirka 1-3 bankdagar.
# www.lysa.se/help-center/228-hur-goer-jag-foer-att-avsluta-mitt-sparande-hos-lysa
#
# ================================================================================
#
# Hur gör jag en intern överföring?
#
# För att göra en intern överföring gör du följande: Hemsidan: > Logga in med
# BankID och klicka på menyn med tre streck uppe till vänster >
# Välj“Överföringar”och“Interna överföringar” > Fyll i från vilket konto du vill
# överföra från och därefter vilket konto du vill överföra till  Appen: > Logga in
# med BankID och klicka på ditt Lysakonto via översikten >
# Välj“Överföring”och“Interna överföringar” > Fyll i från vilket konto du vill
# överföra från och därefter vilket konto du vill överföra till
# www.lysa.se/help-center/229-hur-goer-jag-en-intern-oeverfoering
#
# ================================================================================
#
# Kan jag få ett nytt investeringsförslag från Lysa?
#
# Ja! Du har alltid möjligheten att uppdatera dina svar gällande syn på risk,
# preferenser eller sparhorisont och därigenom få ett nytt investeringsförslag
# från oss. Om din situation eller sparplan ändrats kan du justera dina svar
# enligt följande:  Hemsidan: > Logga in med BankID och klicka på menyn med tre
# streck uppe till vänster> Välj“Kundinfo”och“Investeringsprofil”> Kontrollera
# uppgifterna om din ekonomi och uppdatera om något har förändrats> Klicka dig
# genom flödet och bekräfta dina ändringar genom att klicka på"Nästa"  Appen: >
# Logga in med BankID och klicka på ditt Lysakonto via översikten>
# Välj“Ändra”under rubriken“Kontofokus”> Besvara därefter frågorna för att för att
# få ett uppdaterat förslag av ny målfördelning anpassad baserat på din nuvarande
# situation Lysa rekommenderar att du alltid följer vårt investeringsförslag
# eftersom det är baserat på din syn på risk tillsammans och sparhorisont.
# www.lysa.se/help-center/230-kan-jag-fa-ett-nytt-investeringsfoerslag-fran-lysa
#
# ================================================================================
#
# Vad händer om jag flyttar utomlands?
#
# För att vara Lysakund i Sverige måste du ha din primära skattehemvist i Sverige.
# Flyttar du utomlands och inte längre har din primära skattehemvist i Sverige
# behöver du avsluta ditt engagemang. Däremot kommer vi att lansera i fler EU-
# länder kommande år.Härkan du se vilka länder Lysa finns i.Är du osäker i vilket
# land du har din primära skattehemvist i kan du kontakta Skatteverket som kan
# hjälpa dig.
# www.lysa.se/help-center/231-vad-haender-om-jag-flyttar-utomlands
#
# ================================================================================
#
# Vad är min avgift?
#
# Låga avgifter är otroligt viktigta för ett framgångsrikt långsiktigt sparande.
# Ju lägre avgift du betalar för ditt sparande (dag efter dag, år efter år), desto
# mer pengar blir kvar på ditt konto och får möjlighet att växa. Gör följande för
# att se din avgift:  Hemsidan: > Logga in med BankID och klicka på"Visa mer"på
# önskat Lysa-konto på kontoöversikten > Bläddra till rubriken“Avgifter”. Här går
# det att läsa av din årliga avgift i procent och kronor Appen: > Logga in med
# BankID och klicka på önskat Lysa-konto via översikten > Bläddra till
# rubriken“Avgifter”. Här går det att läsa av din avgift i procent och kronor samt
# se historiska avgifter
# www.lysa.se/help-center/232-vad-aer-min-avgift
#
# ================================================================================
#
# Investera i fonder eller spara på sparkonto?
#
# Investera i fonderAtt investera i fonder ger möjlighet till god avkastning över
# tid. Samtidigt innebär det en risk att pengarna minskar i värde. Hos oss
# investeras dina pengar i en portfölj av indexnära aktie- och räntefonder som
# anpassas efter dina behov. Detta är lämpligt för sparande på minst ett år där
# möjlighet till god avkastning är viktigare för dig än låg risk.Spara på
# Sparkonto AutoAtt spara på Sparkonto Auto är en trygg sparform där du får ränta
# på dina pengar samtidigt som de är skyddade av den statliga insättningsgarantin.
# Det är lämpligt för exempelvis buffertsparande eller kortsiktiga sparmål där låg
# risk är viktigare än hög avkastning.
# www.lysa.se/help-center/233-investera-i-fonder-eller-spara-pa-sparkonto
#
# ================================================================================
#
# Kan jag pausa mitt månadssparande till Lysa?
#
# Det är möjligt att skjuta upp ditt månadssparande en månad åt gången. Det
# innebär att ditt månadssparande dras först nästa månad istället. Gör enligt
# följande för att skjuta upp ett befintligt månadssparande:  Hemsidan: > Logga in
# med BankID och klicka på menyn med tre streck uppe till vänster >
# Välj“Överföringar”och“Månadssparande” > Härnäst klickar du på den gråa
# knappen“Skjut upp 1 månad”. Ångrar du dig kan du trycka på“Återställ”och då sker
# dragningen precis som vanligt  Appen: > Logga in med BankID och gå in på kontot
# där du vill skjuta upp ditt månadssparande > Klicka sedan på ditt månadssparande
# under rubriken“Månadssparande” > Tryck på“Pausa en månad”. Ångrar du dig kan du
# trycka på“Avbryt paus”och då sker dragningen precis som vanligt
# www.lysa.se/help-center/234-kan-jag-pausa-mitt-manadssparande-till-lysa
#
# ================================================================================
#
# Kan jag ta bort mitt månadssparande till Lysa?
#
# Ja, det är möjligt att avsluta ett månadssparande. Gör enligt följande för att
# avsluta ditt månadssparande: Hemsidan:> Logga in med BankID och klicka på menyn
# med tre streck uppe till vänster> Välj“Överföringar”och“Månadssparande”> Härnäst
# klickar du på“Ta bort”Appen:> Logga in med BankID och klicka på kontot du vill
# avsluta månadssparandet för> Klicka sedan på kortet för ditt månadssparande
# under rubriken“Månadssparande”> Härnäst klickar du på“Avsluta månadssparande”och
# bekräftar i nästa steg att du vill avsluta ditt månadssparande Vill du senare
# starta ett månadssparande på nytt kan du enkelt göra det via“Starta nytt
# månadssparande”.
# www.lysa.se/help-center/235-kan-jag-ta-bort-mitt-manadssparande-till-lysa
#
# ================================================================================
#
# Kan jag ändra bank eller kontonummer för mitt månadssparande till Lysa?
#
# Ja, det är möjligt att ändra kontonummer för ditt månadssparande. Tänk på att
# det behöver vara ett transaktionskonto i ditt namn. Du gör enligt följande:
# Hemsidan: > Logga in med BankID och klicka på menyn med tre streck uppe till
# vänster > Välj“Överföringar”och“Månadssparande” > Klicka på“Ta bort”för att
# avsluta det gamla månadssparande > Sedan klickar du på“Starta nytt
# månadssparande”. I det flödet kan du lägga till det nya önskade kontonumret
# Appen: > Logga in med BankID och klicka på kontot du vill ändra månadssparandet
# för > Klicka sedan på kortet för ditt månadssparande under
# rubriken“Månadssparande” > Härnäst klickar du på den röda knappen“Avsluta
# månadssparande”och bekräftar i nästa steg att du är säker på att du vill avsluta
# ditt månadsspar > Sedan klickar du på“Skapa nytt”vid rubriken“Månadssparande”. I
# det flödet kan du lägga till det nya önskade kontonumret
# www.lysa.se/help-center/236-kan-jag-aendra-bank-eller-kontonummer-foer-mitt-manadssparande-till-lysa
#
# ================================================================================
#
# Kan jag ändra belopp eller datum för mitt månadssparande till Lysa?
#
# Ja, det är möjligt att ändra belopp och/eller datum för dragning till ditt
# månadssparande. Gör följande för att ändra: Hemsidan: > Logga in med bankID och
# klicka på menyn med tre streck uppe till vänster> Välj “Överföringar” och
# “Månadssparande”> Justera beloppet under “Belopp” och datum under “Dag för
# månadsdragning”. Glöm inte att trycka på “Uppdatera” efteråt Appen: > Logga in
# med BankID och klicka på det kontot du vill ändra datum eller belopp för >
# Klicka sedan på kortet för ditt månadssparande under rubriken "Månadssparande" >
# Ändra datum för dragningen under "Dag för dragning" och belopp under "Belopp som
# dras varje månad" och spara dina ändringar
# www.lysa.se/help-center/237-kan-jag-aendra-belopp-eller-datum-foer-mitt-manadssparande-till-lysa
#
# ================================================================================
#
# Vad innebär “pågående dragning för ditt månadssparande och du kan återigen justera ditt månadsspar när dragningen är genomförd”?
#
# Det innebär att Lysa har skickat en förfrågan till din bank om att dra det
# angivna beloppet för ditt månadssparande. Det är inte möjligt att skjuta upp,
# ändra eller ta bort ditt månadssparande under denna tid.
# www.lysa.se/help-center/238-vad-innebaer-pagaende-dragning-foer-ditt-manadssparande-och-du-kan-aterigen-justera-ditt-manadsspar-naer-dragningen-aer-genomfoerd
#
# ================================================================================
#
# Hur startar jag ett månadssparande?
#
# Det är möjligt att sätta upp ett månadssparande till ett Lysakonto.
# Månadssparandet innebär att du lägger upp en stående överföring till ett av dina
# Lysakonton samma datum varje månad. Den minsta summan för ett månadssparande är
# 200 kr. Du kan ha flera månadssparanden samtidigt. Om du vill sätta upp ett
# månadssparande till ett Lysakonto gör du följande: Hemsidan: > Logga in med
# BankID och klicka “Månadssparande” uppe till höger. > Klicka på “Starta nytt
# månadssparande” och välj vilken dag överföringen ska göras, till vilket
# Lysakonto pengarna ska och varifrån pengarna ska dras. Appen: > Logga in med
# BankID > Bläddra ned till rubriken “Genvägar” och klicka på “Skapa nytt
# månadssparande”. Följ flödet och välj vilken dag överföringen ska göras, till
# vilket Lysakonto pengarna ska och varifrån pengarna ska dras.
# www.lysa.se/help-center/239-hur-startar-jag-ett-manadssparande
#
# ================================================================================
#
# Varför saknas mitt månadssparande?
#
# Om täckning saknas i samband med att vi försöker dra ditt månadssparande kommer
# ett nytt försök göras nästkommande bankdagar. Totalt görs fem försök att dra
# ditt månadsspar (en varje dag). Om samtliga misslyckas görs inga nya försök
# förrän nästa månad.
# www.lysa.se/help-center/240-varfoer-saknas-mitt-manadssparande
#
# ================================================================================
#
# Hur beskattas interna överföringar?
#
#
# www.lysa.se/help-center/241-hur-beskattas-interna-oeverfoeringar
#
# ================================================================================
#
# Varför ställer vi frågor om din skatterättsliga hemvist?
#
# Lysa har en skyldighet enligt lag att inhämta information om kunder som har
# skatterättslig hemvist i andra länder än Sverige. Vi behöver dela informationen
# med Skatteverket. Du är skyldig att informera Lysa om alla länder där du har
# skatterättslig hemvist och det är viktigt att du lämnar fullständiga och
# uppdaterade uppgifter. Detta eftersom du som kund som är ansvarig för att den
# information du lämnar är korrekt.
# www.lysa.se/help-center/242-varfoer-staeller-vi-fragor-om-din-skatteraettsliga-hemvist
#
# ================================================================================
#
# Vart är min primära skatterättsliga hemvist?
#
# Har du enbart skatterättslig hemvist i ett land, utgör detta land din primära
# skatterättsliga hemvist. Om du har skatterättslig hemvist i flera länder bestäms
# din primära skatterättsliga hemvist av vad som står i det skatteavtal som
# ingåtts mellan de aktuella länderna. Vanligtvis är detta landet du bor i, men
# det finns många olika faktorer som kan påverka och om du är osäker bör du
# kontakta Skatteverket för att få hjälp att göra denna bedömning. Skatteverket
# kan även hjälpa dig att utfärda ett s.k. hemvistintyg vid behov.
# www.lysa.se/help-center/243-vart-aer-min-primaera-skatteraettsliga-hemvist
#
# ================================================================================
#
# Hur behandlas mina personuppgifter hos Lysa?
#
# I samband med att du nyttjar Lysas tjänster eller kommer i kontakt med oss av
# olika anledningar kommer vi att behandla vissa personuppgifter om dig. Lysa
# iakttar stor försiktighet för att skydda din personliga integritet. Behandlingen
# av dina personuppgifter omfattas av bestämmelserna i General Data Protection
# Regulation (GDPR). Lysas kundregister och andra uppgifter som Lysa har om dig
# skyddas även av sekretess enligt 1 kap. 11 § lagen (2007:528) om
# värdepappersmarknaden.Mer information om hur Lysa behandlar dina personuppgifter
# finnshär.
# www.lysa.se/help-center/244-hur-behandlas-mina-personuppgifter-hos-lysa
#
# ================================================================================
#
# Hur skyddas mitt sparande hos Lysa?
#
# Lysa är lika säkert som din bank. Du äger dina fondandelar och du har således
# rätt till hela ditt innehav om Lysa mot förmodan skulle gå i konkurs. Dessutom
# omfattas dina värdepapper av investerarskyddet. Insättningar omfattas av den
# danska motsvarigheten till insättningsgarantin, Garantiformuen, fram till att
# pengarna investeras. För att logga in hos oss använder du BankID. All
# information om ditt sparande är givetvis konfidentiell.Mer information om
# investerarskydd och insättningsgarantin finnshär.
# www.lysa.se/help-center/245-hur-skyddas-mitt-sparande-hos-lysa
#
# ================================================================================
#
# Står Lysa under Finansinpektionens tillsyn?
#
# Ja, Lysa står under Finansinspektionens tillsyn. Mer information om våra
# tillstånd finnshär.
# www.lysa.se/help-center/246-star-lysa-under-finansinpektionens-tillsyn
#
# ================================================================================
#
# Hur gör jag en insättning?
#
# Du kan göra insättningar viahemsidanoch appen.  Hemsidan: > Logga in med BankID
# och klicka på menyn med tre streck uppe till vänster >
# Välj“Överföringar”och“Insättningar” > Sedan väljer du den insättningsmetod som
# passar dig bäst  Appen: > Logga in med BankID och klicka på knappen“Sätt in
# pengar” > Sedan väljer du den insättningsmetod som passar dig bäst När dina
# pengar inkommit till Lysa investeras de automatiskt enligt din valda
# målfördelning inom 1-3 bankdagar.Följande alternativ för engångsinsättning
# finns:
# www.lysa.se/help-center/247-hur-goer-jag-en-insaettning
#
# ================================================================================
#
# Hur kan jag lägga till fler administratörer för mitt företagskonto?
#
# Som företagskund kan du lägga till fler administratörer på ditt konto. Det
# innebär att dessa personer kan logga in på företagets konto och administrera
# det. För att lägga till administratörer gör du följande: > Logga in med BankID
# vialysa.seoch klicka på menyn med tre streck uppe till vänster >
# Välj“Kundinfo”och"Företagsinformation” > Därefter“Hantera användare”för att
# följa stegen för att lägga till en ny administratör
# www.lysa.se/help-center/323-hur-kan-jag-laegga-till-fler-administratoerer-foer-mitt-foeretagskonto
#
# ================================================================================
#
# Hur öppnar jag en kapitalförsäkring?
#
# För att öppna en företagsägd kapitalförsäkring gör företag först ha blivit kund
# och därefter görs följande:> Logga in med BankID pålysa.seoch klicka på menyn
# med tre streck uppe till vänster> Välj "+Öppna konto”på översikten> Klicka på
# "Öppna kapitalförsäkring" och besvara frågorna för att få en personligt anpassad
# målfördelning föreslagenAnnat som kan vara bra att veta är att en
# kapitalförsäkring är i grunden en livförsäkring och därför behöver en person
# vars liv försäkras. En försäkrad till en kapitalförsäkring kan vara vem som
# helst över 18 år. Om personen skulle avlida betalas 101 % av
# försäkringskapitalet ut till företaget.
# www.lysa.se/help-center/324-hur-oeppnar-jag-en-kapitalfoersaekring
#
# ================================================================================
#
# Hur beskattas en kapitalförsäkring?
#
# Kapitalförsäkring är ett schablonbeskattat konto. Det innebär att du inte
# betalar någon skatt för de vinster du gör, istället betalar du en s.k.
# avkastningsskatt i form av en årlig schablonskatt som beräknas på det
# sammanlagda värdet av dina tillgångar på kontot oavsett om du gör vinst eller
# förlust. Skatten på kapitalförsäkring beräknas enligt följande:1. Först beräknas
# kapitalunderlaget. Detta görs genom att man lägger ihop värdet på kontot vid
# ingången av beskattningsåret och de insättningar som gjorts under året.
# Insättningar som görs under första halvåret räknas med till 100 % medan
# insättningar under andra halvåret bara räknas med till 50 %.2. Därefter beräknas
# skatteunderlaget. Skatteunderlaget är en förutbestämd andel av kapitalunderlaget
# och är det belopp som ska tas upp till beskattning. Andelen bestäms av
# statslåneräntan den 30 november föregående år plus en procentenhet. Den kan dock
# aldrig bli lägre än 1,25 %. För 2023 är skatteunderlaget 2,94 % av
# kapitalunderlaget.3. Skatteunderlaget beskattas med en skattesats om 30 %. Detta
# innebär att för 2023 blir skatten på kapitalförsäkring 0,882 % av ditt
# kapitalunderlag (30 % av 2,94 % är 0,882 %).Räkneexempel:Värdet på kontot vid
# årets början (1 januari): 100 000 kr Inbetalningar första halvåret (1 januari
# till 30 juni): 20 000 krInbetalningar andra halvåret (1 juli till 31 december):
# 20 000 krKapitalunderlaget: 100 000 + 20 000 + (50 % av 20 000) = 130 000
# krSkatteunderlaget: 130 000 * 2,94 % = 3 882 krSkatt: 3 882 * 30 % = 1 164,6
# krFöretaget ska inte deklarera några inkomster kopplat till kapitalförsäkring,
# utan försäkringsbolaget som tillhandahåller kapitalförsäkringen sköter
# skatteinbetalningen och tar ut motsvarande belopp från ditt konto.
# www.lysa.se/help-center/325-hur-beskattas-en-kapitalfoersaekring
#
# ================================================================================
#
# Hur beskattas en värdepappersdepå för företag?
#
# Företag som har fondandelar på en värdepappersdepå betalar skatt dels på en
# årlig schablonintäkt, dels på kapitalvinst vid försäljning.Schablonintäkten
# ...
# att finnas förtryckta i din deklaration. Du kan även se ditt
# deklarationsunderlag för respektive konto och år genom att göra följande via
# hemsidan:> Logga in med bankID på lysa.se och klicka på menyn med tre streck
# uppe till vänster> Välj “Kundinfo” och “Deklarationsunderlag”> Klicka i för
# önskat konto och år för att visa beräkningarna och den information vi har
# skickat till Skatteverket
# www.lysa.se/help-center/349-hur-beskattas-ett-investeringssparkonto-isk
#
# ================================================================================
#
# Skattehemvist
#
# Hur vet jag vart jag har skatterättslig hemvist?Du anses normalt ha
# skatterättslig hemvist i det land där du bor. Du kan också anses ha
# skatterättslig hemvist i ett land där du tidigare bott eller om du stadigvarande
# vistas i ett land. Det är möjligt att ha skatterättslig hemvist i flera länder
# samtidigt.Vart är min primära skatterättsliga hemvist?Om du bara har
# skatterättslig hemvist i ett land så utgör detta land din primära
# skatterättsliga hemvist. Om du har skatterättslig hemvist i flera länder bestäms
# din primära skatterättsliga hemvist av vad som står i det skatteavtal som
# ingåtts mellan de aktuella länderna. Vanligtvis är detta det land du bor i, men
# det finns många olika faktorer som kan påverka och om du är osäker bör du
# kontakta Skatteverket för att få hjälp att göra denna bedömning. Om det behövs
# kan Skatteverket också hjälpa dig att utfärda ett s.k. hemvistintyg. Vid frågor
# är du välkommen att kontakta oss.
# www.lysa.se/help-center/350-skattehemvist
#
# ================================================================================
#
# Hur lägger jag till ett uttagskonto?
#
# Hemsidan: > Logga in med BankID pålysa.seoch klicka på menyn med tre streck uppe
# till vänster > Välj“Överföringar”och“Uttag” > Härnäst klickar du på“Nytt uttag”,
# väljer konto och“Nästa” > I steget därefter klickar du på“Lägg till
# bankkonto”och följer instruktionerna Appen: > Logga in med BankID och klicka på
# menyn med tre streck längst ner till höger > Klicka
# på“Uttagskonton”under“Kopplade bankkonton” > Tryck på“+”högst upper till höger
# och följer instruktionerna för att lägga till ditt bankkonto Denna process tar
# 1-2 bankdagar och därefter kan du begära ett uttag. Tänk på att bankkontot måste
# vara ett transaktionskonto och stå i ditt namn.
# www.lysa.se/help-center/352-hur-laegger-jag-till-ett-uttagskonto
#
# ================================================================================
#
# Hur gör jag en stående intern överföring?
#
# Det går bra att sätta upp en stående intern överföring mellan dina konton på
# Lysa. Du kan exempelvis föra över ett belopp på valfri dag varje månad från ditt
# Sparkonto Auto till ett eller flera av dina investeringssparkonton eller
# tvärtom. Överföringen genomförs vid midnatt på din valda dag.För att sätta upp
# en stående intern överföring gör du följande: Hemsidan: > Logga in med BankID
# och klicka på menyn med tre streck uppe till vänster > Välj “Överföringar” och
# “Stående interna överföringar” > Sedan väljer du från ditt önskade konto och
# till ditt önskade konto med belopp & datum. Avslutningsvis behöver du klicka på
# "Godkänn".  App: > Logga in med BankID och välj önskat konto under “Mina konton”
# > Välj “Skapa ny” under rubriken “Stående interna överföringar” i kontovyn >
# Sedan väljer du från ditt önskade konto och till ditt önskade konto med belopp &
# datum. Avslutningsvis behöver du klicka på "Skapa".  Typ av stående intern
# överföring Skatteeffekt ISK → ISK Nej ISK → Sparkonto Nej Sparkonto → ISK Ja.
# Läs merhär. Sparkonto → Sparkonto Nej  Funktionen finns inte för företagskunder
# än utan endast för privatpersoner i Sverige.
# www.lysa.se/help-center/353-hur-goer-jag-en-staende-intern-oeverfoering
#
# ================================================================================
#
# Kan jag ladda ned ett värdebesked från mitt Lysakonto?
#
# Det är möjligt att ladda ner ett värdebesked som innehåller ditt namn,
# personnummer/organisationsnummer och totalt innehav per önskat datum.
# Värdebesked kan användas för att styrka att du har pengar investerade på Lysa.
# För att ladda ned ett värdebesked gör du enligt följande:Appen:> Logga in med
# bankID via appen och klicka på menyn med tre streck nere till höger> Bläddra ned
# till rubriken “Utdrag & dokument” för att välja “Värdebesked”> Härnäst ställer
# du in ditt önskade datum och därefter ladda ned en PDF-fil via hemsidanWebben:>
# Logga in med bankID på lysa.se och klicka på menyn med tre streck uppe till
# vänster> Välj “Kundinfo” och “Värdebesked”> Härnäst ställer du in ditt önskade
# datum och därefter ladda ned en PDF-filOm du önskar en engelsk kopia behöver du
# först översätta ditt Lysakonto till engelska. Observera att detta är endast
# möjligt via webben (lysa.se) och följ dessa steg: > Logga in med bankID igen och
# klicka på menyn med tre streck uppe till vänster> Välj “Kundinfo” och
# “Insättningar”> Härnäst under “Välj språk” är det möjligt att justera till
# engelska/english> Klicka därefter på menyn och välj “Profile” för att sedan
# under “Account Statement” ladda ned en PDF-filOm du behöver någon annan typ av
# intyg, vänligen kontakta oss genom att skicka ett meddelande när du är
# inloggad.Sökord: Engagemangsbesked, kontobevis, kontoutdrag, värdebesked,
# värdeintyg, årsbesked och årsredovisning
# www.lysa.se/help-center/354-kan-jag-ladda-ned-ett-vaerdebesked-fran-mitt-lysakonto
#
# ================================================================================
#
# Can I change the language?
#
# Yes, it is possible to translate Lysa into another language. As of today it is
# possible to translate into English, German or Swedish. Do the following to
# change language:> Log in with bankID on lysa.se and press the top left corner>
# Press on “Kundinfo” and then “Settings”> Afterwards under the header “Välj
# språk” choose if you prefer English, German or SwedishPlease note this feature
# is only available on the web page (lysa.se) yetSökord: English, engelska,
# German, tyska, Swedish och svenska
# www.lysa.se/help-center/355-can-i-change-the-language
#
# ================================================================================
#
# Kan jag ge en annan person fullmakt till mitt Lysakonto?
#
# Det är inte möjligt att ge en annan person fullmakt till ditt Lysakonto. Däremot
# kan du dela ett Lysakonto med en annan Lysakund, vilket innebär att personen får
# insynsrättigheter och kan följa värdeutvecklingen. Personen som får tillgång
# till kontot kan dock inte göra insättningar, uttag eller ändringar i
# sparandet.För att dela ett konto, läs merhär.Observera att kontodelning endast
# kan göras via hemsidan (lysa.se) och är ännu inte tillgänglig i appen.
# Funktionen gäller inte för företagskunder.Sökord: Behörighet, dela konto och
# fullmakt
# www.lysa.se/help-center/356-kan-jag-ge-en-annan-person-fullmakt-till-mitt-lysakonto
#
# ================================================================================
#
# Varför flytta pension till Lysa och hur gör jag?
#
# Varför ska man flytta till Lysa?1)Du får Lysas evidensbaserade förvaltning även
# för din pension.Precis som för ditt privata sparande får du Lysas automatiska
# förvaltning även för de tjänstepensioner du flyttar till Lysa. Välj mellan vårt
# breda och hållbara investeringsfokus och den risk du är bekväm med så ser vi
# därefter till att dina pengar investeras i en bred, global och billig portfölj.
# När flytten till Lysa är genomförd, investeras pengarna automatiskt i enlighet
# med din personliga målfördelning mellan aktier och räntor.2)Låga
# avgifter.Snittkunden betalar totalt0,60 %per år för sitt fribrev hos Lysa. En
# ung kund kan spara miljonbelopp på att flytta till oss jämfört med andra, dyrare
# alternativ.3)Vi hjälper dig att ta rätt risk genom livet och ökar därmed
# sannolikheten för en bra pension.Målfördelningen mellan aktier och räntor
# justeras i takt med att du blir äldre och att pensionsen närmar sig. Detta görs
# genom att vi automatiskt minskar andelen aktier och ökar andelen räntor.4)Det är
# enkelt att flytta.Du kan enkelt begära en flytt digitalt via appen eller
# hemsidan, sen hjälper vi dig genom processen. I vår digitala flyttjänst hjälper
# vi dig att hitta vilka pensioner som du kan flytta och efter att flytten är
# begärd hjälper vi dig genom hela processen. Vi sköter kontakten med din gamla
# arbetsgivare och ser till att flytten genomförs. En flytt tar ofta 3-6 månader,
# beroende på hur snabb administrationen från din gamla arbetsgivare och nuvarande
# försäkringsbolag är.Om du vill ha hjälp att ta reda på vilka försäkringar som
# går att flytta kan du gå in i vår digitala flyttjänst så hjälper vi dig att ta
# reda på det. Kunden finner flyttjänsten genom “+ Öppna konto” via hemsidan
# (lysa.se) samt genom “Genvägar” eller “Nytt konto” i appen.Vilka
# pensionsförsäkringar går att flytta till Lysa?Du kan flytta alla privata
# pensionsförsäkringar och de flesta icke-kollektivavtalade
# tjänstepensionsförsäkringar, som fondförsäkringar och depåförsäkringar, till
# Lysa. För att vara flyttbara får försäkringarna inte ha löpande inbetalningar
# från din nuvarande arbetsgivare. Om du är osäker på vilka försäkringar som kan
# flyttas, hjälper vår digitala flyttjänst dig att identifiera möjligheterna och
# guida dig genom processen.
# www.lysa.se/help-center/358-varfoer-flytta-pension-till-lysa-och-hur-goer-jag
#
# ================================================================================
#
# Vad kostar ett pensionssparande hos Lysa?
#
# För ett pensionssparande på Lysa betalar genomsnittskunden en total årlig avgift
# på cirka0,6 %. Denna avgift inkluderar allt: försäkringsavgiften, Lysas avgift,
# fondavgiften och eventuella transaktionskostnader.Avgifter är en viktig faktor
# att tänka på, särskilt när det gäller långsiktigt sparande som pensionssparande.
# Höga avgifter innebär att mindre pengar blir kvar för att växa genom den
# kraftfulla ränta-på-ränta-effekten. Över tid kan även små skillnader i avgifter
# få en stor inverkan på ditt slutgiltiga pensionskapital. Därför är det klokt att
# välja ett sparande med låga avgifter, så att mer av dina pengar arbetar för
# dig.Läs gärna mer om avgift-på-avgift-effektenhär.
# www.lysa.se/help-center/359-vad-kostar-ett-pensionssparande-hos-lysa
#
# ================================================================================
#
# Utbetalning
#
# För en pensionsförsäkring kan utbetalning påbörjas tidigast från 55 års ålder.
# Som kund hos Lysa kan du få utbetalningar från dina pensionsförsäkringar under
# en period mellan 5 till 40 år. Har du flera pensionsförsäkringar kan du välja
# olika datum för när utbetalning ska påbörjas, samt olika utbetalningstid.Från
# och med 1 januari 2025 kommer det dessutom att bli möjligt att pausa, förkorta
# eller förlänga pågående utbetalningar – även under de första fem åren. Det ger
# dig ökad flexibilitet att hantera din pension i olika livssituationer.Hur
# beskattas tjänstepensionsutbetalningar?Utbetalningar från en pensionsförsäkring
# beskattas som inkomst av tjänst, med en generell skattesats på 30 %. Utöver
# detta tillkommer en årlig schablonskatt som betalas i början av varje år som
# ligger på 0,372 % av försäkringens värde.
# www.lysa.se/help-center/360-utbetalning
#
# ================================================================================
#
# Hur fungerar det med förmånstagare och återbetalningsskydd?
#
# Att ha återbetalningsskydd innebär att om du som kund skulle avlida, utbetalas
# försäkringens värde till dina förmånstagare. Förmånstagare är de personer som
# har rätt att få utbetalning från försäkringen, och det kan vara din maka, make,
# sambo eller i sista hand dina barn.När du flyttar en pensionsförsäkring till
# Lysa tillämpas ett standardförordnande, vilket innebär att förmånstagare i
# första hand är den du är gift eller sambo med, och i andra hand dina barn.Du kan
# välja om du vill ha återbetalningsskydd eller inte när du begär en flytt till
# Lysa, samt även ändra förmånstagare. Detta kan även göras senare, efter att
# flytten är genomförd.Måste jag ha återbetalningsskydd?Nej. Om du väljer bort
# återbetalningsskydd får din försäkring en arvsvinst varje månad, vilket ökar
# värdet på ditt pensionskapital. Vid ditt bortgång tillfaller försäkringsbeloppet
# Lysa istället för en förmånstagare. Detta gör att din pension blir högre än om
# du hade valt återbetalningsskydd. Försäkring utan återbetalningsskydd passar
# vanligtvis dig som är ensamstående eller har anhöriga som inte är beroende av
# ditt pensionskapital.
# www.lysa.se/help-center/361-hur-fungerar-det-med-foermanstagare-och-aterbetalningsskydd
#
# ================================================================================
#
# Vad kan man flytta till Lysa?
#
# Du kan flytta alla privata pensionsförsäkringar och de flesta icke-
# kollektivavtalade tjänstepensionsförsäkringar, som fondförsäkringar och
# depåförsäkringar, till Lysa.För att vara flyttbara får försäkringarna inte ha
# löpande inbetalningar från din nuvarande arbetsgivare. Om du är osäker på vilka
# försäkringar som kan flyttas, hjälper vår digitala flyttjänst dig att
# identifiera möjligheterna och guida dig genom processen.Lysa tar inte ut några
# flyttavgifter. Däremot kan ditt nuvarande försäkringsbolag ta ut en avgift för
# att genomföra flytten, som dras från beloppet som överförs. För 2024 får denna
# avgift vara högst 728 kronor för fond- och depåförsäkringar. Under 2025 ligger
# maxavgiften på 747 kronor.Efter att du begärt en flytt kan du enkelt följa
# statusen via översikten i inloggat läge, både på webben och i appen.Vad kan man
# inte flytta till Lysa?- Aktiv tjänstepension från nuvarande arbetsgivare-
# Kollektiv avtalad pension- Individuellt pensionssparande (IPS)- Tjänstepension
# under utbetbalningOm du vill ha hjälp att ta reda på vilka försäkringar som går
# att flytta kan du gå in i vår digitala flyttjänst så hjälper vi dig att ta reda
# på det. Kunden finner flyttjänsten genom “+ Öppna konto” via hemsidan (lysa.se)
# samt genom “Genvägar” eller “Nytt konto” i appen.
# www.lysa.se/help-center/362-vad-kan-man-flytta-till-lysa
#
# ================================================================================
#
# Privat pensionsförsäkring
#
# En privat pensionsförsäkring är ett sparande där du som privatperson avsätter
# pengar till din pension i en pensionsförsäkring. Före 2016 kunde man göra avdrag
# i deklarationen för insättningar till en sådan försäkring, därefter försvann
# möjligheten och därför är det oftast inte längre fördelaktigt att teckna en ny
# en privat pensionsförsäkring. Likt en tjänstepension gäller samma regler för
# flyttmöjligheter och utbetalning, som kan börja vid 55 års ålder och pågå mellan
# 5 och 40 år hos Lysa.De flesta privata pensionsförsäkringar går att flytta till
# Lysa, och processen är oftast snabbare än tjänstepensioner eftersom inget
# godkännande från den gamla arbetsgivaren krävs. För att se om din
# pensionsförsäkring kan flyttas, rekommenderar vi att du använder vår digitala
# flyttjänst som hjälper dig genom processen.
# www.lysa.se/help-center/363-privat-pensionsfoersaekring
#
# ================================================================================
#
# Säkerhet och kundskydd
#
# Som försäkringskund hos Lysa har du enligt lag en särskild förmånsrätt om Lysa
# mot förmodan skulle gå i konkurs. Det innebär att som kund har rätt att få ut
# dina pengar före övriga fordringsägare. Din förmånsrätt är inte
# beloppsbegränsad, utan omfattar hela ditt försäkringskapital.Läs mer om
# säkerhethär.
# www.lysa.se/help-center/364-saekerhet-och-kundskydd
#
# ================================================================================
#
# Hur kontaktar jag er?
#
# Har du frågor om Lysa? Något vi kan förbättra eller bara säga hej? Hör gärna av
# dig, via mejl eller telefon direkt.Telefon:010 551 32 30vardagar mellan
# 09:00-18:00Meddelande och mejl: vardagar mellan 09:00-18:00Du kan även skicka
# ett meddelande sominloggad kund direkthär.Mejl:kontakt@lysa.seÄr du företagare?
# Tveka inte kontakta oss direkthär:foretag@lysa.se
# www.lysa.se/help-center/81-hur-kontaktar-jag-er
#
# ================================================================================
#
# Loaded 74 items from kd_base.json

# %%
import numpy as np
import faiss
from langchain_openai import OpenAIEmbeddings
import os
import dotenv

dotenv.load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

def get_vector_db():

    # Initiera OpenAIEmbeddings med din API-nyckel
    openai_embeddings = OpenAIEmbeddings(openai_api_key=api_key)

    # Skapa en lista med "context" från kd_base
    texts = [item['context'] for item in kd_base.values()]

    # Beräkna embeddings för varje text med OpenAI-modellen
    embeddings = openai_embeddings.embed_documents(texts)
    embeddings = np.array(embeddings).astype('float32')
    d = embeddings.shape[1]

    # Bygg ett FAISS-index för vektorsökning (L2-avstånd)
    index = faiss.IndexFlatL2(d)
    index.add(embeddings)

    print(f"Vector store byggt med {index.ntotal} vektorer.")

    # Spara FAISS-indexet till fil
    faiss.write_index(index, "faiss_index.index")
    print("FAISS-index sparat till 'faiss_index.index'.")

    # Spara embeddings i en NumPy-fil
    np.save("embeddings.npy", embeddings)
    print("Embeddings sparade till 'embeddings.npy'.")

    return openai_embeddings, embeddings, index

get_vector_db()

openai_embeddings = OpenAIEmbeddings(openai_api_key=api_key)
embeddings = np.load("embeddings.npy")
index = faiss.read_index("faiss_index.index")
# Out:
# Vector store byggt med 74 vektorer.
# FAISS-index sparat till 'faiss_index.index'.
# Embeddings sparade till 'embeddings.npy'.

# %%
# Definiera en fråga
query = "vad är lysa?"

# Generera embeddings för frågan med OpenAI
query_embedding = openai_embeddings.embed_query(query)
query_embedding = np.array(query_embedding, dtype='float32').reshape(1, -1)

# Definiera hur många toppresultat vi vill hämta
top_k = 5

# Utför FAISS-sökning
distances, indices = index.search(query_embedding, top_k)

# Skriv ut resultaten
for i, idx in enumerate(indices[0]):
    print(f"Match {i+1}")
    print("Title:", kd_base[str(idx)]["title"])
    print("Context:", kd_base[str(idx)]["context"])
    print("Source:", kd_base[str(idx)]["source"])
    print()
# Out:
# Match 1
# Title: Hur kontaktar jag er?
# Context: Har du frågor om Lysa? Något vi kan förbättra eller bara säga hej? Hör gärna av dig, via mejl eller telefon direkt.Telefon:010 551 32 30vardagar mellan 09:00-18:00Meddelande och mejl: vardagar mellan 09:00-18:00Du kan även skicka ett meddelande sominloggad kund direkthär.Mejl:kontakt@lysa.seÄr du företagare? Tveka inte kontakta oss direkthär:foretag@lysa.se
#
#
#
# Source: www.lysa.se/help-center/81-hur-kontaktar-jag-er
#
# Match 2
# Title: Varför flytta pension till Lysa och hur gör jag?
# Context: Varför ska man flytta till Lysa?1)Du får Lysas evidensbaserade förvaltning även för din pension.Precis som för ditt privata sparande får du Lysas automatiska förvaltning även för de tjänstepensioner du flyttar till Lysa. Välj mellan vårt breda och hållbara investeringsfokus och den risk du är bekväm med så ser vi därefter till att dina pengar investeras i en bred, global och billig portfölj. När flytten till Lysa är genomförd, investeras pengarna automatiskt i enlighet med din personliga målfördelning mellan aktier och räntor.2)Låga avgifter.Snittkunden betalar totalt0,60 %per år för sitt fribrev hos Lysa. En ung kund kan spara miljonbelopp på att flytta till oss jämfört med andra, dyrare alternativ.3)Vi hjälper dig att ta rätt risk genom livet och ökar därmed sannolikheten för en bra pension.Målfördelningen mellan aktier och räntor justeras i takt med att du blir äldre och att pensionsen närmar sig. Detta görs genom att vi automatiskt minskar andelen aktier och ökar andelen räntor.4)Det är enkelt att flytta.Du kan enkelt begära en flytt digitalt via appen eller hemsidan, sen hjälper vi dig genom processen. I vår digitala flyttjänst hjälper vi dig att hitta vilka pensioner som du kan flytta och efter att flytten är begärd hjälper vi dig genom hela processen. Vi sköter kontakten med din gamla arbetsgivare och ser till att flytten genomförs. En flytt tar ofta 3-6 månader, beroende på hur snabb administrationen från din gamla arbetsgivare och nuvarande försäkringsbolag är.Om du vill ha hjälp att ta reda på vilka försäkringar som går att flytta kan du gå in i vår digitala flyttjänst så hjälper vi dig att ta reda på det. Kunden finner flyttjänsten genom “+ Öppna konto” via hemsidan (lysa.se) samt genom “Genvägar” eller “Nytt konto” i appen.Vilka pensionsförsäkringar går att flytta till Lysa?Du kan flytta alla privata pensionsförsäkringar och de flesta icke-kollektivavtalade tjänstepensionsförsäkringar, som fondförsäkringar och depåförsäkringar, till Lysa. För att vara flyttbara får försäkringarna inte ha löpande inbetalningar från din nuvarande arbetsgivare. Om du är osäker på vilka försäkringar som kan flyttas, hjälper vår digitala flyttjänst dig att identifiera möjligheterna och guida dig genom processen.
#
#
# Source: www.lysa.se/help-center/358-varfoer-flytta-pension-till-lysa-och-hur-goer-jag
#
# Match 3
# Title: Vad är Lysas investeringsfilosofi?
# Context: Lysa är en spartjänst som automatiskt investerar dina pengar i några av marknadens bredaste och billigaste indexnära aktiefonder och ränteinstrument. Dessutom anpassas risknivån i ditt sparande baserat på just din situation och dina preferenser. Vår investeringsfilosofi bygger på historisk data, sannolikhetslära och nobelprisvinnande forskning i ekonomi. Detta samt insikten om att ingen kan se in i framtiden och därigenom veta exakt vilka aktier eller fonder som kommer prestera bättre än andra. Genom att investera brett (globalt och indexnära) och billigt är ditt sparande på Lysa utformat för att vara förberett på att precis vad som helst kan hända. Vår tjänst bygger på fyra enklagrundprinciper:1. Betala låga avgifter2. Sprid dina investeringar - god diversifiering minskar risken3. Ta inte större risker än du kan hantera4. Fullfölj din sparstrategiDu kan läsa merhärom Lysas investeringsfilosofi.
#
# Source: www.lysa.se/help-center/222-vad-aer-lysas-investeringsfilosofi
#
# Match 4
# Title: Vad händer om jag flyttar utomlands?
# Context: För att vara Lysakund i Sverige måste du ha din primära skattehemvist i Sverige. Flyttar du utomlands och inte längre har din primära skattehemvist i Sverige behöver du avsluta ditt engagemang. Däremot kommer vi att lansera i fler EU-länder kommande år.Härkan du se vilka länder Lysa finns i.Är du osäker i vilket land du har din primära skattehemvist i kan du kontakta Skatteverket som kan hjälpa dig.
#
# Source: www.lysa.se/help-center/231-vad-haender-om-jag-flyttar-utomlands
#
# Match 5
# Title: Hur behandlas mina personuppgifter hos Lysa?
# Context: I samband med att du nyttjar Lysas tjänster eller kommer i kontakt med oss av olika anledningar kommer vi att behandla vissa personuppgifter om dig. Lysa iakttar stor försiktighet för att skydda din personliga integritet. Behandlingen av dina personuppgifter omfattas av bestämmelserna i General Data Protection Regulation (GDPR). Lysas kundregister och andra uppgifter som Lysa har om dig skyddas även av sekretess enligt 1 kap. 11 § lagen (2007:528) om värdepappersmarknaden.Mer information om hur Lysa behandlar dina personuppgifter finnshär.
#
# Source: www.lysa.se/help-center/244-hur-behandlas-mina-personuppgifter-hos-lysa

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt-4o")

# %%
def calculate_percentage(value: float, total: float) -> float:
    """Returns the percentage of value relative to total.
    
    Args:
        value (float): The value to calculate percentage.
        total (float): The total value.
    """
    if total == 0:
        return 0.0
    return (value / total) * 100

def percentage_of_value(percent: float, amount: float) -> float:
    """Returns the percentage of amount based on percent.
    
    Args:
        percent (float): The percentage value.
        amount (float): The total amount.
    """
    return (percent / 100.0) * amount

# %%
def search(query: str, top_k: int = 10) -> list:
    """
    Utför en vektorsökning över kunskapsbasen av frågor (kd_base) med hjälp av den globala modellen och FAISS-indexet.

    Args:
    query (str): Frågesträngen att söka efter.
    top_k (int, valfritt): Antal toppresultat att returnera. Standard är 5.

    Returns:
    list: En lista med ordböcker, där varje ordbok innehåller "title", "context" och "distance" för ett resultat.
    """
    if not query.strip():
        return []

    # Encode query using OpenAI embeddings.
    # Note: OpenAIEmbeddings.embed_query returns a list of floats.
    embedding_vector = openai_embeddings.embed_query(query)
    # Convert to a numpy array of type float32 and reshape to (1, -1)
    embedding = np.array(embedding_vector, dtype='float32').reshape(1, -1)
    
    distances, indices = index.search(embedding, top_k)

    results = []
    for i, idx in enumerate(indices[0]):
        idx_int = int(idx)
        try:
            entry = kd_base[idx_int] if isinstance(kd_base, list) else list(kd_base.values())[idx_int]
        except (IndexError, KeyError):
            continue

        results.append({
            "title": entry.get("title", "No Title"),
            "context": entry.get("context", "No Context"),
            "source": entry.get("source", "No Source"),
            "distance": float(distances[0][i])
        })

    return results

# %%
tools = [percentage_of_value, calculate_percentage, search]

llm_with_tools = llm.bind_tools(tools)

# %%
from langgraph.graph import MessagesState
from langchain_core.messages import HumanMessage, SystemMessage

sys_msg = SystemMessage(
    "Hej! Jag är en kundsupportagent och kan hjälpa dig med grundläggande information om vår tjänst, Lysa. "
    "Om jag inte har svaret på din fråga, hänvisar jag dig gärna till vår kundsupport för vidare hjälp."
)

# %%
# Node
def reasoner(state:MessagesState):
    return {"messages": [llm_with_tools.invoke([sys_msg] + state["messages"])]}

# %%
from langgraph.graph import START, StateGraph
from langgraph.prebuilt import tools_condition
from langgraph.prebuilt import ToolNode
from IPython.display import Image, display

# Graph 
builder = StateGraph(MessagesState)

# Add nodes 
builder.add_node("reasoner", reasoner)
builder.add_node("tools", ToolNode(tools))

# Add edges
builder.add_edge(START, "reasoner")
builder.add_conditional_edges(
    "reasoner",
    tools_condition,
)
builder.add_edge("tools", "reasoner")
react_graph = builder.compile()

# Display the graph
display(Image(react_graph.get_graph(xray=True).draw_mermaid_png()))

# %%
messages = [HumanMessage(content="vad är avgiften för att använda lysa?")]
messages = react_graph.invoke({"messages": messages})

# %%
for m in messages["messages"]:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# vad är avgiften för att använda lysa?
# ================================== Ai Message ==================================
#
# Lysa har en total avgift som består av tre delar:
#
# 1. **Förvaltningsavgift:** Lysa tar ut en förvaltningsavgift som kan variera beroende på hur mycket pengar du har investerat. Avgiften ligger vanligtvis mellan 0,24% och 0,39% per år.
#
# 2. **Fondavgifter:** Dessa är de underliggande avgifterna för de fonder som ingår i din portfölj. Dessa avgifter varierar beroende på vilka fonder som används men ligger ofta runt 0,10% till 0,15% per år.
#
# 3. **Kostnader för handel:** Det kan även finnas små kostnader relaterade till handel inom din portfölj.
#
# Det är alltid bra att besöka Lysas officiella webbplats eller kontakta deras kundtjänst för att få den mest aktuella och detaljerade informationen om avgifter.

# %%
messages = [HumanMessage(content="hur mycket avgiften för att använda lysa om jag har 356230,54kr?")]
messages = react_graph.invoke({"messages": messages})

# %%
for m in messages["messages"]:
    m.pretty_print()
# Out:
# ================================ Human Message =================================
#
# hur mycket avgiften för att använda lysa om jag har 356230,54kr?
# ================================== Ai Message ==================================
#
# Lysa har en avgiftsstruktur som består av två delar: Lysas egen avgift och fondavgifter. Den totala avgiften ligger vanligtvis mellan 0,3% och 0,4% per år. För en mer exakt beräkning, låt oss anta att den totala avgiften är 0,35%.
#
# Skulle du vilja att jag räknar ut det exakta beloppet för dig baserat på denna procentsats?

# %% [markdown]
# ## More complexity with routing difficult questions away from model.

# %%
#If the agent can't answer the question, it will recommend the customer to contact the customer support.
messages = [HumanMessage(content="jag vill att ni stänger av mitt konto")]
messages = react_graph.invoke({"messages": messages})

msg = ""
for m in messages["messages"]:
    # Access specific properties of the message
    if hasattr(m, 'content'):
        msg += f"Content: {m.content}\n"
    if hasattr(m, 'type'):
        msg += f"Type: {m.type}\n"
    if hasattr(m, 'role'):
        msg += f"Role: {m.role}\n"
    msg += "="*80 + "\n\n"  # Separator between messages
    
    # The pretty_print() can stay as is
    m.pretty_print()

# %%
# !pip install discord
# !pip install streamlit-jupyter
# Out:
# Requirement already satisfied: discord in /home/morrissimons/miniconda3/lib/python3.12/site-packages (2.3.2)
# Requirement already satisfied: discord.py>=2.3.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from discord) (2.4.0)
# Requirement already satisfied: aiohttp<4,>=3.7.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from discord.py>=2.3.2->discord) (3.11.11)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (0.2.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (1.18.3)
# Requirement already satisfied: idna>=2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp<4,>=3.7.4->discord.py>=2.3.2->discord) (3.7)
# Collecting streamlit-jupyter
#   Downloading streamlit_jupyter-0.2.1-py3-none-any.whl.metadata (8.1 kB)
# Collecting fastcore (from streamlit-jupyter)
#   Downloading fastcore-1.7.29-py3-none-any.whl.metadata (3.6 kB)
# Collecting ipywidgets==7.7.2 (from streamlit-jupyter)
#   Downloading ipywidgets-7.7.2-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting jupyter (from streamlit-jupyter)
#   Downloading jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# Collecting stqdm (from streamlit-jupyter)
#   Downloading stqdm-0.0.5-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: streamlit>=1.19 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.42.0)
# Collecting tabulate (from streamlit-jupyter)
#   Downloading tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: tqdm in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (4.66.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (6.29.5)
# Collecting ipython-genutils~=0.2.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Requirement already satisfied: traitlets>=4.3.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (5.14.3)
# Collecting widgetsnbextension~=3.6.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading widgetsnbextension-3.6.10-py2.py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: ipython>=4.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (8.31.0)
# Collecting jupyterlab-widgets<3,>=1.0.0 (from ipywidgets==7.7.2->streamlit-jupyter)
#   Downloading jupyterlab_widgets-1.1.11-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: altair<6,>=4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.2)
# Requirement already satisfied: packaging<25,>=20 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (6.4.2)
# Collecting notebook (from jupyter->streamlit-jupyter)
#   Downloading notebook-7.3.2-py3-none-any.whl.metadata (10 kB)
# Collecting jupyter-console (from jupyter->streamlit-jupyter)
#   Downloading jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# Collecting nbconvert (from jupyter->streamlit-jupyter)
#   Downloading nbconvert-7.16.6-py3-none-any.whl.metadata (8.5 kB)
# Collecting jupyterlab (from jupyter->streamlit-jupyter)
#   Downloading jupyterlab-4.3.5-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: jinja2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (1.25.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.12)
# Requirement already satisfied: comm>=0.1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.0)
# Requirement already satisfied: psutil in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (26.2.0)
# Requirement already satisfied: decorator in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.19.1)
# Requirement already satisfied: stack_data in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (3.0.0)
# Collecting jupyter-server<3,>=2.4.0 (from notebook->jupyter->streamlit-jupyter)
#   Downloading jupyter_server-2.15.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting jupyterlab-server<3,>=2.27.1 (from notebook->jupyter->streamlit-jupyter)
#   Downloading jupyterlab_server-2.27.3-py3-none-any.whl.metadata (5.9 kB)
# Collecting notebook-shim<0.3,>=0.2 (from notebook->jupyter->streamlit-jupyter)
#   Downloading notebook_shim-0.2.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting async-lru>=1.0.0 (from jupyterlab->jupyter->streamlit-jupyter)
#   Downloading async_lru-2.0.4-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx>=0.25.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (0.28.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab->jupyter->streamlit-jupyter)
#   Downloading jupyter_lsp-2.2.5-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.13.1)
# Collecting bleach!=5.0.0 (from bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter)
#   Downloading bleach-6.2.0-py3-none-any.whl.metadata (30 kB)
# Collecting defusedxml (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading defusedxml-0.7.1-py2.py3-none-any.whl.metadata (32 kB)
# Collecting jupyterlab-pygments (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markupsafe>=2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (3.0.2)
# Collecting mistune<4,>=2.0.3 (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading mistune-3.1.1-py3-none-any.whl.metadata (1.7 kB)
# Collecting nbclient>=0.5.0 (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading nbclient-0.10.2-py3-none-any.whl.metadata (8.3 kB)
# Collecting nbformat>=5.7 (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading nbformat-5.10.4-py3-none-any.whl.metadata (3.6 kB)
# Collecting pandocfilters>=1.4.1 (from nbconvert->jupyter->streamlit-jupyter)
#   Downloading pandocfilters-1.5.1-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: webencodings in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (0.5.1)
# Collecting tinycss2<1.5,>=1.1.0 (from bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter)
#   Downloading tinycss2-1.4.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (5.0.2)
# Requirement already satisfied: anyio in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (4.3.6)
# Collecting argon2-cffi>=21.1 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading argon2_cffi-23.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting jupyter-events>=0.11.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading jupyter_events-0.12.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jupyter-server-terminals>=0.4.4 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl.metadata (5.6 kB)
# Collecting overrides>=5.0 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting prometheus-client>=0.9 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading prometheus_client-0.21.1-py3-none-any.whl.metadata (1.8 kB)
# Collecting send2trash>=1.8.2 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading Send2Trash-1.8.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting terminado>=0.8.3 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading terminado-0.18.1-py3-none-any.whl.metadata (5.8 kB)
# Collecting websocket-client>=1.7 (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading websocket_client-1.8.0-py3-none-any.whl.metadata (8.0 kB)
# Collecting babel>=2.10 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter)
#   Downloading babel-2.17.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter)
#   Downloading json5-0.10.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: mdurl~=0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (0.1.2)
# Collecting fastjsonschema>=2.15 (from nbformat>=5.7->nbconvert->jupyter->streamlit-jupyter)
#   Downloading fastjsonschema-2.21.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: ptyprocess>=0.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit-jupyter) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (1.3.1)
# Collecting argon2-cffi-bindings (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Collecting python-json-logger>=2.0.4 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading python_json_logger-3.2.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: pyyaml>=5.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (6.0.2)
# Collecting rfc3339-validator (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting rfc3986-validator>=0.1.1 (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting fqdn (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading fqdn-1.5.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: isoduration in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.1)
# Collecting uri-template (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading uri_template-1.3.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting webcolors>=24.6.0 (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter)
#   Downloading webcolors-24.11.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: cffi>=1.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.9.0.20241206)
# Downloading streamlit_jupyter-0.2.1-py3-none-any.whl (13 kB)
# Downloading ipywidgets-7.7.2-py2.py3-none-any.whl (123 kB)
# Downloading fastcore-1.7.29-py3-none-any.whl (84 kB)
# Downloading jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Downloading stqdm-0.0.5-py3-none-any.whl (11 kB)
# Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Downloading ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Downloading jupyterlab_widgets-1.1.11-py3-none-any.whl (246 kB)
# Downloading widgetsnbextension-3.6.10-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.0 MB/s eta 0:00:00
# Downloading notebook-7.3.2-py3-none-any.whl (13.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.2/13.2 MB 10.7 MB/s eta 0:00:0000:0100:01
# Downloading jupyterlab-4.3.5-py3-none-any.whl (11.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 11.2 MB/s eta 0:00:0000:010:01
# Downloading jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# Downloading nbconvert-7.16.6-py3-none-any.whl (258 kB)
# Downloading async_lru-2.0.4-py3-none-any.whl (6.1 kB)
# Downloading bleach-6.2.0-py3-none-any.whl (163 kB)
# Downloading jupyter_lsp-2.2.5-py3-none-any.whl (69 kB)
# Downloading jupyter_server-2.15.0-py3-none-any.whl (385 kB)
# Downloading jupyterlab_server-2.27.3-py3-none-any.whl (59 kB)
# Downloading mistune-3.1.1-py3-none-any.whl (53 kB)
# Downloading nbclient-0.10.2-py3-none-any.whl (25 kB)
# Downloading nbformat-5.10.4-py3-none-any.whl (78 kB)
# Downloading notebook_shim-0.2.4-py3-none-any.whl (13 kB)
# Downloading pandocfilters-1.5.1-py2.py3-none-any.whl (8.7 kB)
# Downloading defusedxml-0.7.1-py2.py3-none-any.whl (25 kB)
# Downloading jupyterlab_pygments-0.3.0-py3-none-any.whl (15 kB)
# Downloading argon2_cffi-23.1.0-py3-none-any.whl (15 kB)
# Downloading babel-2.17.0-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 11.2 MB/s eta 0:00:00 0:00:01
# Downloading fastjsonschema-2.21.1-py3-none-any.whl (23 kB)
# Downloading json5-0.10.0-py3-none-any.whl (34 kB)
# Downloading jupyter_events-0.12.0-py3-none-any.whl (19 kB)
# Downloading jupyter_server_terminals-0.5.3-py3-none-any.whl (13 kB)
# Downloading overrides-7.7.0-py3-none-any.whl (17 kB)
# Downloading prometheus_client-0.21.1-py3-none-any.whl (54 kB)
# Downloading Send2Trash-1.8.3-py3-none-any.whl (18 kB)
# Downloading terminado-0.18.1-py3-none-any.whl (14 kB)
# Downloading tinycss2-1.4.0-py3-none-any.whl (26 kB)
# Downloading websocket_client-1.8.0-py3-none-any.whl (58 kB)
# Downloading python_json_logger-3.2.1-py3-none-any.whl (14 kB)
# Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Downloading argon2_cffi_bindings-21.2.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (86 kB)
# Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Downloading webcolors-24.11.1-py3-none-any.whl (14 kB)
# Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Downloading uri_template-1.3.0-py3-none-any.whl (11 kB)
# Installing collected packages: ipython-genutils, fastjsonschema, websocket-client, webcolors, uri-template, tinycss2, terminado, tabulate, send2trash, rfc3986-validator, rfc3339-validator, python-json-logger, prometheus-client, pandocfilters, overrides, mistune, jupyterlab-widgets, jupyterlab-pygments, json5, fqdn, fastcore, defusedxml, bleach, babel, async-lru, jupyter-server-terminals, argon2-cffi-bindings, argon2-cffi, nbformat, jupyter-console, nbclient, jupyter-events, stqdm, nbconvert, jupyter-server, notebook-shim, jupyterlab-server, jupyter-lsp, jupyterlab, notebook, widgetsnbextension, ipywidgets, jupyter, streamlit-jupyter
#   Attempting uninstall: jupyterlab-widgets
#     Found existing installation: jupyterlab_widgets 3.0.13
#     Uninstalling jupyterlab_widgets-3.0.13:
#       Successfully uninstalled jupyterlab_widgets-3.0.13
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 4.0.13
#     Uninstalling widgetsnbextension-4.0.13:
#       Successfully uninstalled widgetsnbextension-4.0.13
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 8.1.5
#     Uninstalling ipywidgets-8.1.5:
#       Successfully uninstalled ipywidgets-8.1.5
# Successfully installed argon2-cffi-23.1.0 argon2-cffi-bindings-21.2.0 async-lru-2.0.4 babel-2.17.0 bleach-6.2.0 defusedxml-0.7.1 fastcore-1.7.29 fastjsonschema-2.21.1 fqdn-1.5.1 ipython-genutils-0.2.0 ipywidgets-7.7.2 json5-0.10.0 jupyter-1.1.1 jupyter-console-6.6.3 jupyter-events-0.12.0 jupyter-lsp-2.2.5 jupyter-server-2.15.0 jupyter-server-terminals-0.5.3 jupyterlab-4.3.5 jupyterlab-pygments-0.3.0 jupyterlab-server-2.27.3 jupyterlab-widgets-1.1.11 mistune-3.1.1 nbclient-0.10.2 nbconvert-7.16.6 nbformat-5.10.4 notebook-7.3.2 notebook-shim-0.2.4 overrides-7.7.0 pandocfilters-1.5.1 prometheus-client-0.21.1 python-json-logger-3.2.1 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 send2trash-1.8.3 stqdm-0.0.5 streamlit-jupyter-0.2.1 tabulate-0.9.0 terminado-0.18.1 tinycss2-1.4.0 uri-template-1.3.0 webcolors-24.11.1 websocket-client-1.8.0 widgetsnbextension-3.6.10

# %% [markdown]
# # Use later

# %%
# import requests
# from dotenv import load_dotenv
# 
# webhook_url = os.getenv("DISCORD_WEBHOOK_URL")
# 
# requests.post(webhook_url, data={"content":"Just testing!"})

# %%
# requests.post(webhook_url, data={"content":msg})

# %%
# !pip uninstall streamlit-jupyter -y
# !pip install streamlit-jupyter
# Out:
# Found existing installation: streamlit-jupyter 0.2.1
# Uninstalling streamlit-jupyter-0.2.1:
#   Successfully uninstalled streamlit-jupyter-0.2.1
# Collecting streamlit-jupyter
#   Using cached streamlit_jupyter-0.2.1-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: fastcore in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.7.29)
# Requirement already satisfied: ipywidgets==7.7.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (7.7.2)
# Requirement already satisfied: jupyter in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.1.1)
# Requirement already satisfied: stqdm in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (0.0.5)
# Requirement already satisfied: streamlit>=1.19 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (1.42.0)
# Requirement already satisfied: tabulate in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (0.9.0)
# Requirement already satisfied: tqdm in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit-jupyter) (4.66.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (6.29.5)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (8.31.0)
# Requirement already satisfied: jupyterlab-widgets<3,>=1.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipywidgets==7.7.2->streamlit-jupyter) (1.1.11)
# Requirement already satisfied: altair<6,>=4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.2)
# Requirement already satisfied: packaging<25,>=20 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (24.1)
# Requirement already satisfied: pandas<3,>=1.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from streamlit>=1.19->streamlit-jupyter) (6.4.2)
# Requirement already satisfied: notebook in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (7.3.2)
# Requirement already satisfied: jupyter-console in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (7.16.6)
# Requirement already satisfied: jupyterlab in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter->streamlit-jupyter) (4.3.5)
# Requirement already satisfied: jinja2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (1.25.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (4.0.12)
# Requirement already satisfied: comm>=0.1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.8.12)
# Requirement already satisfied: jupyter-client>=6.1.12 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (1.6.0)
# Requirement already satisfied: psutil in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (6.1.1)
# Requirement already satisfied: pyzmq>=24 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (26.2.0)
# Requirement already satisfied: decorator in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.19.1)
# Requirement already satisfied: stack_data in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from requests<3,>=2.27->streamlit>=1.19->streamlit-jupyter) (2024.12.14)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from notebook->jupyter->streamlit-jupyter) (0.2.4)
# Requirement already satisfied: async-lru>=1.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (2.2.5)
# Requirement already satisfied: setuptools>=40.8.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab->jupyter->streamlit-jupyter) (75.1.0)
# Requirement already satisfied: beautifulsoup4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (4.13.1)
# Requirement already satisfied: bleach!=5.0.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (3.0.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (3.1.1)
# Requirement already satisfied: nbclient>=0.5.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbconvert->jupyter->streamlit-jupyter) (1.5.1)
# Requirement already satisfied: webencodings in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter->streamlit-jupyter) (1.4.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.19->streamlit-jupyter) (5.0.2)
# Requirement already satisfied: anyio in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (4.8.0)
# Requirement already satisfied: httpcore==1.* in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (0.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.8.4)
# Requirement already satisfied: attrs>=22.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.19->streamlit-jupyter) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets==7.7.2->streamlit-jupyter) (4.3.6)
# Requirement already satisfied: argon2-cffi>=21.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (23.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.21.1)
# Requirement already satisfied: send2trash>=1.8.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter->streamlit-jupyter) (0.10.0)
# Requirement already satisfied: mdurl~=0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.19->streamlit-jupyter) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from nbformat>=5.7->nbconvert->jupyter->streamlit-jupyter) (2.21.1)
# Requirement already satisfied: ptyprocess>=0.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.7.0)
# Requirement already satisfied: wcwidth in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.13)
# Requirement already satisfied: six>=1.5 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.19->streamlit-jupyter) (1.17.0)
# Requirement already satisfied: soupsieve>1.2 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert->jupyter->streamlit-jupyter) (2.6)
# Requirement already satisfied: executing>=1.2.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (2.1.0)
# Requirement already satisfied: asttokens>=2.1.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (3.0.0)
# Requirement already satisfied: pure_eval in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from stack_data->ipython>=4.0.0->ipywidgets==7.7.2->streamlit-jupyter) (0.2.3)
# Requirement already satisfied: sniffio>=1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from anyio->httpx>=0.25.0->jupyterlab->jupyter->streamlit-jupyter) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (21.2.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (6.0.2)
# Requirement already satisfied: rfc3339-validator in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (0.1.1)
# Requirement already satisfied: fqdn in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.5.1)
# Requirement already satisfied: isoduration in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.1)
# Requirement already satisfied: uri-template in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.17.1)
# Requirement already satisfied: pycparser in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /home/morrissimons/miniconda3/lib/python3.12/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter->streamlit-jupyter) (2.9.0.20241206)
# Using cached streamlit_jupyter-0.2.1-py3-none-any.whl (13 kB)
# Installing collected packages: streamlit-jupyter
# Successfully installed streamlit-jupyter-0.2.1

# %%
import streamlit as st
from streamlit_jupyter import StreamlitPatcher
from langchain_core.messages import HumanMessage

# Enable Streamlit components in Jupyter
StreamlitPatcher().jupyter()

# Use Streamlit as usual
st.title("Interactive App")

user_query = st.text_input("Enter your query:")

if st.button("Send"):
    if user_query:
        messages = [HumanMessage(content=user_query)]
        response = react_graph.invoke({"messages": messages})
        for m in response["messages"]:
            st.write(m.content)
    else:
        st.write("Please enter a query.")
# Out:
# # Interactive App
# Textarea(value='', description='Enter your query:', placeholder='Type something')
# 2025-02-05 01:08:17.603 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 01:08:17.604 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 01:08:17.604 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 01:08:17.605 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-02-05 01:08:17.627
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/morrissimons/miniconda3/lib/python3.12/site-packages/ipykernel_launcher.py [ARGUMENTS]
# 2025-02-05 01:08:17.627 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit_jupyter
print(dir(streamlit_jupyter))
# Out:
# ['IN_IPYTHON', 'StreamlitPatcher', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', '__version__', 'core', 'tqdm', 'utils']
